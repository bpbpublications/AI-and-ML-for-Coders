# %%
# import pandas, numpy
# matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Create a sample dataframe with missing values
df = pd.DataFrame({'Country': ['US', 'India', np.nan, 'UK', 'Canada'],
                  'City': ['New York', 'Delhi', np.nan, 'London', 'Toronto']})

# Replace missing values in the 'Country' column with the most frequent country
most_frequent_country = df['Country'].mode()[0]
df['Country'].fillna(most_frequent_country, inplace=True)

# Print the updated dataframe
print(df)
# Out:
#   Country      City
# 0      US  New York
# 1   India     Delhi
# 2  Canada       NaN
# 3      UK    London
# 4  Canada   Toronto

# %%
# download population data
# source: https://raw.githubusercontent.com/datasets/population/main/data/population.csv
# load it as a dataframe
df_population = pd.read_csv('https://raw.githubusercontent.com/datasets/population/main/data/population.csv')

# %%
# check top 5 sample rows of
# the population dataframe
df_population.head()
# Out:
#   Country Name Country Code  Year  Value
# 0        Aruba          ABW  1960  54608
# 1        Aruba          ABW  1961  55811
# 2        Aruba          ABW  1962  56682
# 3        Aruba          ABW  1963  57475
# 4        Aruba          ABW  1964  58178

# %%
# in the population dataframe, convert the 'Country Name'
# column to only 'Country'
df_population.rename(columns={'Country Name': 'Country'}, inplace=True)
df_population.head()
# Out:
#   Country Country Code  Year  Value
# 0   Aruba          ABW  1960  54608
# 1   Aruba          ABW  1961  55811
# 2   Aruba          ABW  1962  56682
# 3   Aruba          ABW  1963  57475
# 4   Aruba          ABW  1964  58178

# %%
# convert the 'Country' column values
# in the population dataframe to Camel case
df_population['Country'] = df_population['Country'].str.title()
df_population.head()
# Out:
#   Country Country Code  Year  Value
# 0   Aruba          ABW  1960  54608
# 1   Aruba          ABW  1961  55811
# 2   Aruba          ABW  1962  56682
# 3   Aruba          ABW  1963  57475
# 4   Aruba          ABW  1964  58178

# %%
# join our earlier dataframe 'df'
# with the population dataframe 'df_population'
# using inner join in Country column
# and City column
# and save it as 'df'
df = df.merge(df_population, on='Country', how='inner')
df
# Out:
#     Country     City Country Code  Year      Value
# 0     India    Delhi          IND  1960  445954579
# 1     India    Delhi          IND  1961  456351876
# 2     India    Delhi          IND  1962  467024193
# 3     India    Delhi          IND  1963  477933619
# 4     India    Delhi          IND  1964  489059309
# ..      ...      ...          ...   ...        ...
# 181  Canada  Toronto          CAN  2017   36545236
# 182  Canada  Toronto          CAN  2018   37065084
# 183  Canada  Toronto          CAN  2019   37601230
# 184  Canada  Toronto          CAN  2020   38037204
# 185  Canada  Toronto          CAN  2021   38246108
#
# [186 rows x 5 columns]

# %%
# aggregate the dataframe on Value column
# and create a new dataframe with Country, City and Value columns
df_agg = df.groupby(['Country', 'City'])['Value'].sum().reset_index()
df_agg
# Out:
#   Country     City        Value
# 0  Canada  Toronto   1727442450
# 1   India    Delhi  55782631401
